# %%
from lxml import html

# %%
import requests

# %%
import json

# %% [markdown]
# Написать приложение и функцию, которые собирают основные новости с сайта на выбор lenta.ru, mail.ru, dzen.ru . Для парсинга использовать XPath
# Структура данных должна содержать:
# * название источника
# * наименование новости
# * ссылку на новость
# * дата публикации
# минимум один сайт максимум все.
#
# Подсказка 1. У ленты нет даты в новости. Посмотрите откуда ее взять
# Подсказка 2. У дзена и mail нет своих новостей. Нужно найти источник.

# %%
url = 'https://lenta.ru'
header = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 YaBrowser/23.1.1.1138 Yowser/2.5 Safari/537.36',
}
response = requests.get(url, headers=header)

# %%
dom = html.fromstring(response.text)

# %%
news_list = dom.xpath("//a[contains(@class, 'card-mini')]")   #("//div[contains(@class, 'topnews__column')]")

# %%
news_list[0].xpath('./@href')
# Out:
# ['/news/2023/09/27/pugacheva_galkin/']

# %%
news_list[0].xpath("./div/h3[contains(@class, 'card-mini__title')]/text()")
# Out:
# ['У уехавших из России Пугачевой и Галкина снизились доходы']

# %%
news_list[0].xpath("./div/div/time/text()")[0]
# Out:
# '14:45'

# %%
news_dict = {}
for news in news_list:
    news_title = news.xpath("./div/h3[contains(@class, 'card-mini__title')]/text()")[0]
    if news.xpath('./@href')[0][0:4] == 'http':
        news_link = news.xpath('./@href')[0]
    else:
        news_link = url + news.xpath('./@href')[0]
    news_date = news.xpath('./@href')[0][6:16]
    news_time = news.xpath("./div/div/time/text()")
    news_dict[news_title] = {
        'link': news_link,
        'date': news_date,
        'time': news_time,
    }
print(news_dict)
# Out:
# {'У уехавших из России Пугачевой и Галкина снизились доходы': {'link': 'https://lenta.ru/news/2023/09/27/pugacheva_galkin/', 'date': '2023/09/27', 'time': ['14:45']}, 'Сергей Собянин утвердил состав правительства Москвы после переизбрания': {'link': 'https://lenta.ru/news/2023/09/27/sostav_mer/', 'date': '2023/09/27', 'time': ['14:42']}, 'Штурм спецназом незаконных обменных пунктов валюты попал на видео': {'link': 'https://moslenta.ru/news/city/shturm-27-09-2023.htm/', 'date': '//moslenta', 'time': ['14:39']}, 'Российские электромобили призвали уподобить троллейбусам': {'link': 'https://lenta.ru/news/2023/09/27/electromobil_trolley/', 'date': '2023/09/27', 'time': ['14:38']}, 'Фигуранта дела о теракте у посольства России в Кабуле признали виновным': {'link': 'https://lenta.ru/news/2023/09/27/terakt/', 'date': '2023/09/27', 'time': ['14:35']}, 'ФАС потребовала от продавцов раскрыть цены на бензин': {'link': 'https://lenta.ru/news/2023/09/27/benz/', 'date': '2023/09/27', 'time': ['14:35']}, 'В гараже у россиянина нашли танковое оружие и снаряды': {'link': 'https://lenta.ru/news/2023/09/27/tanks/', 'date': '2023/09/27', 'time': ['14:34']}, 'Свердловский автохам Игорь Новоселов получил новый срок': {'link': 'https://lenta.ru/news/2023/09/27/avtoham/', 'date': '2023/09/27', 'time': ['14:31']}, 'Российский врач назвала приводящие к старению омолаживающие процедуры': {'link': 'https://lenta.ru/news/2023/09/27/starenie_krasota/', 'date': '2023/09/27', 'time': ['14:28']}, 'Грядущее повышение цен на суши и роллы объяснили': {'link': 'https://lenta.ru/news/2023/09/27/fish_ru/', 'date': '2023/09/27', 'time': ['14:27']}, 'Космонавты вернулись на Землю после самого долгого полета в истории МКС': {'link': 'https://lenta.ru/news/2023/09/27/sms232/', 'date': '2023/09/27', 'time': ['14:18']}, 'Песков прокомментировал обращение Хиллари Клинтон к Путину': {'link': 'https://lenta.ru/news/2023/09/27/peskov_on_clinton/', 'date': '2023/09/27', 'time': ['14:14']}, 'В российском регионе обнаружили древние жилища каменного века': {'link': 'https://lenta.ru/news/2023/09/27/drevnie/', 'date': '2023/09/27', 'time': ['14:14']}, 'У Genesis появился купеобразный кроссовер': {'link': 'https://motor.ru/news/genesis-gv80-27-09-2023.htm', 'date': '//motor.ru', 'time': ['14:13']}, 'Рост российского города объяснили потоками мигрантов': {'link': 'https://lenta.ru/news/2023/09/27/rossia/', 'date': '2023/09/27', 'time': ['14:07']}, 'Стали известны подробности задержания бывшего главы правительства Карабаха': {'link': 'https://lenta.ru/news/2023/09/27/vardanyan_gpsaz/', 'date': '2023/09/27', 'time': ['14:05']}, 'Рената Литвинова отреагировала на окончание забастовки сценаристов Голливуда': {'link': 'https://lenta.ru/news/2023/09/27/win/', 'date': '2023/09/27', 'time': ['14:02']}, 'Шойгу проинспектировал производство высокоточного оружия': {'link': 'https://lenta.ru/news/2023/09/27/ktrv/', 'date': '2023/09/27', 'time': ['13:59']}, 'МИД России указал на отработку США действий по переброске запрещенных ракет': {'link': 'https://lenta.ru/news/2023/09/27/949384398/', 'date': '2023/09/27', 'time': []}, 'Объявленный ВСУ ликвидированным командующий Черноморским флотом дал интервью': {'link': 'https://lenta.ru/news/2023/09/27/chfsh/', 'date': '2023/09/27', 'time': []}, 'Крупнейшая криптовалютная биржа уйдет из России': {'link': 'https://lenta.ru/news/2023/09/27/bin_rus/', 'date': '2023/09/27', 'time': []}, 'В ЛНР рассказали об эвакуации ВСУ раненой «важной персоны» из района Сватово': {'link': 'https://lenta.ru/news/2023/09/27/persona/', 'date': '2023/09/27', 'time': []}, 'На Западе озвучили страшный для Зеленского сценарий по Украине. Реальна ли для страны перспектива раскола на две части?': {'link': 'https://lenta.ru/news/2023/09/27/pais_ukraine/', 'date': '2023/09/27', 'time': []}, 'Гильдия сценаристов Голливуда объявила о завершении забастовки': {'link': 'https://lenta.ru/news/2023/09/27/zabastovka/', 'date': '2023/09/27', 'time': []}, 'Захарова прокомментировала доклад ко ...

# %%
with open('top_news_lenta.json', 'w', encoding='utf-8') as f:
    json.dump(news_dict, f, ensure_ascii=False)

# %%
news_dict
# Out:
# {'У уехавших из России Пугачевой и Галкина снизились доходы': {'link': 'https://lenta.ru/news/2023/09/27/pugacheva_galkin/',
#   'date': '2023/09/27',
#   'time': ['14:45']},
#  'Сергей Собянин утвердил состав правительства Москвы после переизбрания': {'link': 'https://lenta.ru/news/2023/09/27/sostav_mer/',
#   'date': '2023/09/27',
#   'time': ['14:42']},
#  'Штурм спецназом незаконных обменных пунктов валюты попал на видео': {'link': 'https://moslenta.ru/news/city/shturm-27-09-2023.htm/',
#   'date': '//moslenta',
#   'time': ['14:39']},
#  'Российские электромобили призвали уподобить троллейбусам': {'link': 'https://lenta.ru/news/2023/09/27/electromobil_trolley/',
#   'date': '2023/09/27',
#   'time': ['14:38']},
#  'Фигуранта дела о теракте у посольства России в Кабуле признали виновным': {'link': 'https://lenta.ru/news/2023/09/27/terakt/',
#   'date': '2023/09/27',
#   'time': ['14:35']},
#  'ФАС потребовала от продавцов раскрыть цены на бензин': {'link': 'https://lenta.ru/news/2023/09/27/benz/',
#   'date': '2023/09/27',
#   'time': ['14:35']},
#  'В гараже у россиянина нашли танковое оружие и снаряды': {'link': 'https://lenta.ru/news/2023/09/27/tanks/',
#   'date': '2023/09/27',
#   'time': ['14:34']},
#  'Свердловский автохам Игорь Новоселов получил новый срок': {'link': 'https://lenta.ru/news/2023/09/27/avtoham/',
#   'date': '2023/09/27',
#   'time': ['14:31']},
#  'Российский врач назвала приводящие к старению омолаживающие процедуры': {'link': 'https://lenta.ru/news/2023/09/27/starenie_krasota/',
#   'date': '2023/09/27',
#   'time': ['14:28']},
#  'Грядущее повышение цен на суши и роллы объяснили': {'link': 'https://lenta.ru/news/2023/09/27/fish_ru/',
#   'date': '2023/09/27',
#   'time': ['14:27']},
#  'Космонавты вернулись на Землю после самого долгого полета в истории МКС': {'link': 'https://lenta.ru/news/2023/09/27/sms232/',
#   'date': '2023/09/27',
#   'time': ['14:18']},
#  'Песков прокомментировал обращение Хиллари Клинтон к Путину': {'link': 'https://lenta.ru/news/2023/09/27/peskov_on_clinton/',
#   'date': '2023/09/27',
#   'time': ['14:14']},
#  'В российском регионе обнаружили древние жилища каменного века': {'link': 'https://lenta.ru/news/2023/09/27/drevnie/',
#   'date': '2023/09/27',
#   'time': ['14:14']},
#  'У Genesis появился купеобразный кроссовер': {'link': 'https://motor.ru/news/genesis-gv80-27-09-2023.htm',
#   'date': '//motor.ru',
#   'time': ['14:13']},
#  'Рост российского города объяснили потоками мигрантов': {'link': 'https://lenta.ru/news/2023/09/27/rossia/',
#   'date': '2023/09/27',
#   'time': ['14:07']},
#  'Стали известны подробности задержания бывшего главы правительства Карабаха': {'link': 'https://lenta.ru/news/2023/09/27/vardanyan_gpsaz/',
#   'date': '2023/09/27',
#   'time': ['14:05']},
#  'Рената Литвинова отреагировала на окончание забастовки сценаристов Голливуда': {'link': 'https://lenta.ru/news/2023/09/27/win/',
#   'date': '2023/09/27',
#   'time': ['14:02']},
#  'Шойгу проинспектировал производство высокоточного оружия': {'link': 'https://lenta.ru/news/2023/09/27/ktrv/',
#   'date': '2023/09/27',
#   'time': ['13:59']},
#  'МИД России указал на отработку США действий по переброске запрещенных ракет': {'link': 'https://lenta.ru/news/2023/09/27/949384398/',
#   'date': '2023/09/27',
#   'time': []},
#  'Объявленный ВСУ ликвидированным командующий Черноморским флотом дал интервью': {'link': 'https://lenta.ru/news/2023/09/27/chfsh/',
#   'date': '2023/09/27',
#   'time': []},
#  'Крупнейшая криптовалютная биржа уйдет из России': {'link': 'https://lenta.ru/news/2023/09/27/bin_rus/',
#   'date': '2023/09/27',
#   'time': []},
#  'В ЛНР рассказали об эвакуации ВСУ раненой «важной персоны» из района Сватово': {'link': 'https://lenta.ru/news/2023/09/27/persona/',
#   'date': '2023/09/27',
#   'time': []},
#  'На Западе озвучили страшный для Зеленского сценарий по Украине. Реальна ли для страны перспектива раскола на две части?': {'link': 'https://lenta.ru/news/2023/09/27/pais_ukraine/',
#   'date': '2023/09/27',
#   'time': []},
#  'Гильдия сценаристов Голливуда объявила о завершении забастовки': {'link': 'https://lenta.ru/news/2023/09/27/zabastovka/',
#   'date': '2023/09/27',
#   'time': []},
#  'Захарова прокомментировала доклад комиссии ООН по Украине': {'link': 'https://lenta.ru/news/2023/09/27/8743874384/',
#   'date': '2023/09/27',
#   'time': ['13:58']},
#  'Дачников научили ускорять созревание компоста': {'link': 'https://lenta.ru/news/2023/09/27/sredstvo/',
#   'date': '2023/09/27',
#   'time': ['13:57']},
#  'Китайской экономике предрекли замедление': {'link': 'https://lenta.ru/news/2023/09/27/chi_ec/',
#   'date': '2023/09/27',
#   'time': ['13:54']},
#  'Иммунолог указал на странности в сезоне гриппа и ОРВИ в России': {'link': 'https://lenta.ru/news/2023/09/27/szn/',
#   'date': '2023/09/27',
#   'time': ['13:53']},
#  'Запрет на вывоз из России лома драгметаллов задумали продлить': {'link': 'https://lenta.ru/news/2023/09/27/lom/',
#   'date': '2023/09/27',
#   'time': ['13:53']},
#  'В Москве раскрыли совершенное 24 года назад изнасилование и убийство': {'link': 'https://moslenta.ru/news/lyudi/raskryli-iznasilovanie-i-ubiistvo-27-09-2023.htm/',
#   'date': '//moslenta',
#   'time': ['13:48']},
#  'Бузова дала невысоким девушкам совет по стилю': {'link': 'https://lenta.ru/news/2023/09/27/buzstyle/',
#   'date': '2023/09/27',
#   'time': ['13:44']},
#  'Внезапный рост цен на бензин в России объяснили': {'link': 'https://lenta.ru/news/2023/09/27/rastet/',
#   'date': '2023/09/27',
#   'time': ['13:45']},
#  'Песков отреагировал на статью Херша о теракте на «Северных потоках»': {'link': 'https://lenta.ru/news/2023/09/27/herssshh/',
#   'date': '2023/09/27',
#   'time': ['13:45']},
#  'Отнявшего жизнь женщины-фельдшера россиянина арестовали': {'link': 'https://lenta.ru/news/2023/09/27/tomsk/',
#   'date': '2023/09/27',
#   'time': ['13:44']},
#  'В Кремле прокомментировали приветствие Зеленским ветерана СС в Канаде': {'link': 'https://lenta.ru/news/2023/09/27/peskov27/',
#   'date': '2023/09/27',
#   'time': ['13:43']},
#  'На Украине назвали число обесточенных населенных пунктов': {'link': 'https://lenta.ru/news/2023/09/27/nolight/',
#   'date': '2023/09/27',
#   'time': ['13:41']},
#  'Обнаружение обломков беспилотника в Саратовской области подтвердили': {'link': 'https://lenta.ru/news/2023/09/27/eddds/',
#   'date': '2023/09/27',
#   'time': ['13:40']},
#  'ВВС США завершили эксплуатацию следившего за Россией самолета': {'link': 'https://lenta.ru/news/2023/09/27/e8/',
#   'date': '2023/09/27',
#   'time': ['13:38']},
#  'Диетолог назвала три важных для здоровья печени продукта': {'link': 'https://lenta.ru/news/2023/09/27/dlya_pecheni/',
#   'date': '2023/09/27',
#   'time': ['13:33']},
#  'На Украине вынесли обвинения бывшему адвокату Медведчука': {'link': 'https://lenta.ru/news/2023/09/27/sburybin/',
#   'date': '2023/09/27',
#   'time': ['13:33']},
#  'Губернатор отреагировал на идею Эстонии переименовать Калининград': {'link': 'https://lenta.ru/news/2023/09/27/pereimenovat/',
#   'date': '2023/09/27',
#   'time': ['13:32']},
#  'Некоторых россиян предложили освободить от налога с продажи квартиры': {'link': 'https://lenta.ru/news/2023/09/27/svo_kvartiry/',
#   'date': '2023/09/27',
#   'time': ['13:31']},
#  'Россиян предупредили о сокращении выбора автомобилей': {'link': 'https://lenta.ru/news/2023/09/27/avtostat/',
#   'date': '2023/09/27',
#   'time': ['13:29']},
#  'Зеленского обвинили в неблагодарности западным союзникам': {'link': 'https://lenta.ru/news/2023/09/27/646457757347/',
#   'date': '2023/09/27',
#   'time': ['13:25']},
#  'Агата Муцениеце в бикини показала ягодицы на видео': {'link': 'https://moslenta.ru/news/lyudi/muceniece-pokazala-yagodicy-27-09-2023.htm',
#   'date': '//moslenta',
#   'time': ['13:24']},
#  'Китайцы массово устремились в Москву': {'link': 'https://lenta.ru/news/2023/09/27/china_msk/',
#   'date': '2023/09/27',
#   'time': ['13:21']},
#  'Участница шоу «Голос. Дети» стала жертвой мошенников': {'link': 'https://lenta.ru/news/2023/09/27/golos_moshenniki/',
#   'date': '2023/09/27',
#   'time': ['13:21']},
#  'Володин назвал Зеленского позором еврейского народа': {'link': 'https://lenta.ru/news/2023/09/27/volodin/',
#   'date': '2023/09/27',
#   'time': ['13:20']},
#  'Названы способы быстрее продать квартиру': {'link': 'https://lenta.ru/news/2023/09/27/bystree/',
#   'date': '2023/09/27',
#   'time': ['13:20']},
#  'Шляпу Майкла Джексона продали на аукционе почти за восемь миллионов рублей': {'link': 'https://lenta.ru/news/2023/09/27/jackson/',
#   'date': '2023/09/27',
#   'time': ['13:19']},
#  'Российских киберспортсменов лишили приза в 200 тысяч долларов из-за гражданства': {'link': 'https://lenta.ru/news/2023/09/27/cybersport/',
#   'date': '2023/09/27',
#   'time': ['13:14']},
#  'Звезда двух фильмов «Брат» раскритиковал третью часть': {'link': 'https://lenta.ru/news/2023/09/27/suhorukov_say/',
#   'date': '2023/09/27',
#   'time': ['13:12']},
#  'Канделаки сообщила о задержании бывшего главы правительства Карабаха': {'link': 'https://lenta.ru/news/2023/09/27/kandelaki_vardanyan/',
#   'date': '2023/09/27',
#   'time': ['13:07']},
#  'Полуголый мужчина с собакой на коленях устроил на гольф-каре гонки с полицией': {'link': 'https://lenta.ru/news/2023/09/27/dog_race/',
#   'date': '2023/09/27',
#   'time': ['13:07']},
#  'Дело «заказавшей» соперницу экс-директора школы Масловой рассмотрят повторно': {'link': 'https://lenta.ru/news/2023/09/27/zakaz/',
#   'date': '2023/09/27',
#   'time': ['13:06']},
#  'Косметолог назвала идеальные для кожи и волос продукты': {'link': 'https://lenta.ru/news/2023/09/27/food/',
#   'date': '2023/09/27',
#   'time': ['13:02']},
#  'В российском регионе юноши вывезли мигранта в лес для издевательств': {'link': 'https://lenta.ru/news/2023/09/27/chelisd/',
#   'date': '2023/09/27',
#   'time': ['13:01']},
#  'Россиянам предрекли резкое подорожание суши и роллов': {'link': 'https://moslenta.ru/news/lyudi/podorozhanie-rollov-27-09-2023.htm/',
#   'date': '//moslenta',
#   'time': ['12:59']},
#  'Названы минусы одного типа частных домов': {'link': 'https://lenta.ru/news/2023/09/27/nekach/',
#   'date': '2023/09/27',
#   'time': ['12:58']},
#  'Более трети россиян провели лето без отпуска': {'link': 'https://lenta.ru/news/2023/09/27/rus_dos/',
#   'date': '2023/09/27',
#   'time': ['12:54']},
#  'Назван способ избежать выгорания на работе': {'link': 'https://lenta.ru/news/2023/09/27/vygoraniye_no/',
#   'date': '2023/09/27',
#   'time': ['12:52']},
#  'Для iPhone выпустили снижающее излучение обновление': {'link': 'https://lenta.ru/news/2023/09/27/apple_france/',
#   'date': '2023/09/27',
#   'time': ['12:50']},
#  'Еврокомиссия начала подготовку реформ для расширения ЕС': {'link': 'https://lenta.ru/news/2023/09/27/eu_reforms/',
#   'date': '2023/09/27',
#   'time': ['12:49']},
#  'Создатели «Очень странных дел» возобновили работу над сериалом': {'link': 'https://lenta.ru/news/2023/09/27/st/',
#   'date': '2023/09/27',
#   'time': ['12:49']},
#  'Названа дата открытия магазинов Decathlon в России': {'link': 'https://lenta.ru/news/2023/09/27/decathlonopening/',
#   'date': '2023/09/27',
#   'time': ['12:48']},
#  'Пожар в частном доме в Щелково попытались выдать за ЧП на военных объектах': {'link': 'https://lenta.ru/news/2023/09/27/schelkovo/',
#   'date': '2023/09/27',
#   'time': ['12:46']},
#  'Сурков назвал причину упущенного шанса России стать частью НАТО': {'link': 'https://lenta.ru/news/2023/09/27/surkovss/',
#   'date': '2023/09/27',
#   'time': ['12:45']},
#  'Роспотребнадзор назвал напряженной ситуацию с птичьим гриппом в России': {'link': 'https://lenta.ru/news/2023/09/27/situaciya_gripp/',
#   'date': '2023/09/27',
#   'time': ['12:43']},
#  'Появились подробности о сбитом под Саратовом беспилотнике': {'link': 'https://lenta.ru/news/2023/09/27/dronnn/',
#   'date': '2023/09/27',
#   'time': ['12:43']},
#  'Взрывы на «Северных потоках» были зафиксированы норвежскими учеными': {'link': 'https://lenta.ru/news/2023/09/27/norway_science/',
#   'date': '2023/09/27',
#   'time': ['12:42']},
#  'МИД оценил возможную передачу Киеву ракет ATACMS': {'link': 'https://lenta.ru/news/2023/09/27/atac/',
#   'date': '2023/09/27',
#   'time': ['12:41']},
#  'Япония нашла решение проблемы мирового электронного мусора': {'link': 'https://lenta.ru/news/2023/09/27/yaponia_electron/',
#   'date': '2023/09/27',
#   'time': ['12:40']},
#  'Из квартиры народного артиста СССР вынесли пять миллионов рублей': {'link': 'https://lenta.ru/news/2023/09/27/krazha/',
#   'date': '2023/09/27',
#   'time': ['12:40']},
#  'В Литве назвали уровень расходов на оборону с начала конфликта на Украине': {'link': 'https://lenta.ru/news/2023/09/27/20/',
#   'date': '2023/09/27',
#   'time': ['12:37']},
#  'В США рассказали о легкой мишени для военных России на Украине': {'link': 'https://lenta.ru/news/2023/09/27/abrams_abrams/',
#   'date': '2023/09/27',
#   'time': ['12:37']},
#  'Россиянам напомнили о льготах за ЖКХ': {'link': 'https://lenta.ru/news/2023/09/27/lgoti/',
#   'date': '2023/09/27',
#   'time': ['12:35']},
#  'Малолетний зацепер погиб от удара током на крыше подмосковной электрички': {'link': 'https://moslenta.ru/news/lyudi/maloletnii-zaceper-27-09-2023.htm/',
#   'date': '//moslenta',
#   'time': ['12:34']},
#  'Китаец спрятал полмиллиона рублей в кроссовках и попался на российской таможне': {'link': 'https://lenta.ru/news/2023/09/27/sneakers/',
#   'date': '2023/09/27',
#   'time': ['12:24']},
#  'Захарова ответила президенту Молдавии на обвинения в адрес России': {'link': 'https://lenta.ru/news/2023/09/27/zaharovasandu/',
#   'date': '2023/09/27',
#   'time': ['12:23']},
#  'Миру предрекли рекордное усиление угрожающего явления': {'link': 'https://lenta.ru/news/2023/09/27/nino_weather/',
#   'date': '2023/09/27',
#   'time': ['12:18']},
#  'Леонардо Ди Каприо познакомил мать с 25-летней возлюбленной': {'link': 'https://lenta.ru/news/2023/09/27/leoroman/',
#   'date': '2023/09/27',
#   'time': ['12:14']},
#  'Звезда «Универа» раскрыла пол четвертого ребенка': {'link': 'https://moslenta.ru/news/lyudi/zvezda-univera-27-09-2023.htm',
#   'date': '//moslenta',
#   'time': ['12:13']},
#  'Ведущая «Жди меня» назвала причину ухода из программы': {'link': 'https://lenta.ru/news/2023/09/27/arnt/',
#   'date': '2023/09/27',
#   'time': ['12:12']},
#  'Мужчина попытался провезти через границу 180 килограммов наркотика в огурцах': {'link': 'https://lenta.ru/news/2023/09/27/ogurtsu/',
#   'date': '2023/09/27',
#   'time': ['12:11']},
#  'Выявлена способность бактерий использовать антибиотики для роста': {'link': 'https://lenta.ru/news/2023/09/27/bactery/',
#   'date': '2023/09/27',
#   'time': ['12:10']},
#  'Торговые сети выступили против дистанционной торговли алкоголем в России': {'link': 'https://lenta.ru/news/2023/09/27/acort_alcohol/',
#   'date': '2023/09/27',
#   'time': ['12:04']},
#  'Бойца «Азова» осудили на 22 года за обстрел из миномета школы под Мариуполем': {'link': 'https://lenta.ru/news/2023/09/27/gvpsud/',
#   'date': '2023/09/27',
#   'time': ['12:01']}}

# %%
def get_lenta_news():
    url = 'https://lenta.ru'
    header = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 YaBrowser/23.1.1.1138 Yowser/2.5 Safari/537.36',
    }
    response = requests.get(url, headers=header)
    dom = html.fromstring(response.text)
    news_list = dom.xpath("//a[contains(@class, 'card-mini')]")
    news_dict = {}
    for news in news_list:
        news_title = news.xpath("./div/h3[contains(@class, 'card-mini__title')]/text()")[0]
        if news.xpath('./@href')[0][0:4] == 'http':
            news_link = news.xpath('./@href')[0]
        else:
            news_link = url + news.xpath('./@href')[0]
        news_date = news.xpath('./@href')[0][6:16]
        news_time = news.xpath("./div/div/time/text()")
        news_dict[news_title] = {
            'link': news_link,
            'date': news_date,
            'time': news_time,
        }
    print(news_dict)

# %%
get_lenta_news()
# Out:
# {'Во Франции рассказали о росте экономики в России': {'link': 'https://lenta.ru/news/2023/09/27/rooost/', 'date': '2023/09/27', 'time': ['15:19']}, 'Путин проведет встречу с президентом Южного Судана': {'link': 'https://lenta.ru/news/2023/09/27/south_sudan/', 'date': '2023/09/27', 'time': ['15:19']}, 'ВСУ повторно обстреляли российское село': {'link': 'https://lenta.ru/news/2023/09/27/obstrel/', 'date': '2023/09/27', 'time': ['15:19']}, 'Звезда «6 кадров» рассказала о разнице французских и русских жен': {'link': 'https://lenta.ru/news/2023/09/27/difference/', 'date': '2023/09/27', 'time': ['15:18']}, 'Представительство Карабаха прокомментировало задержание Варданяна': {'link': 'https://lenta.ru/news/2023/09/27/andrian/', 'date': '2023/09/27', 'time': ['15:15']}, 'Власти объяснили использование фотошопа для вручения россиянину медали за СВО': {'link': 'https://lenta.ru/news/2023/09/27/explain/', 'date': '2023/09/27', 'time': ['15:14']}, 'Стало известно о возвращении бывших подчиненных Пригожина под Артемовск': {'link': 'https://lenta.ru/news/2023/09/27/back/', 'date': '2023/09/27', 'time': ['15:13']}, 'Россиянин решил участвовать в СВО на стороне Украины и попал под статью': {'link': 'https://lenta.ru/news/2023/09/27/gosizmenkrkras/', 'date': '2023/09/27', 'time': ['15:11']}, 'В Британии заявили о провале контрнаступления Украины': {'link': 'https://lenta.ru/news/2023/09/27/zelen/', 'date': '2023/09/27', 'time': ['15:07']}, 'Apple отменила выпуск дешевых очков дополненной реальности': {'link': 'https://lenta.ru/news/2023/09/27/vision/', 'date': '2023/09/27', 'time': ['15:00']}, 'У уехавших из России Пугачевой и Галкина снизились доходы': {'link': 'https://lenta.ru/news/2023/09/27/pugacheva_galkin/', 'date': '2023/09/27', 'time': ['14:45']}, 'Песков прокомментировал обращение Хиллари Клинтон к Путину': {'link': 'https://lenta.ru/news/2023/09/27/peskov_on_clinton/', 'date': '2023/09/27', 'time': ['14:14']}, 'Российские электромобили призвали уподобить троллейбусам': {'link': 'https://lenta.ru/news/2023/09/27/electromobil_trolley/', 'date': '2023/09/27', 'time': ['14:38']}, 'Фигуранта дела о теракте у посольства России в Кабуле признали виновным': {'link': 'https://lenta.ru/news/2023/09/27/terakt/', 'date': '2023/09/27', 'time': ['14:35']}, 'В гараже у россиянина нашли танковое оружие и снаряды': {'link': 'https://lenta.ru/news/2023/09/27/tanks/', 'date': '2023/09/27', 'time': ['14:34']}, 'Свердловский автохам Игорь Новоселов получил новый срок': {'link': 'https://lenta.ru/news/2023/09/27/avtoham/', 'date': '2023/09/27', 'time': ['14:31']}, 'Российский врач назвала приводящие к старению омолаживающие процедуры': {'link': 'https://lenta.ru/news/2023/09/27/starenie_krasota/', 'date': '2023/09/27', 'time': ['14:28']}, 'Грядущее повышение цен на суши и роллы объяснили': {'link': 'https://lenta.ru/news/2023/09/27/fish_ru/', 'date': '2023/09/27', 'time': ['14:27']}, 'МИД России указал на отработку США действий по переброске запрещенных ракет': {'link': 'https://lenta.ru/news/2023/09/27/949384398/', 'date': '2023/09/27', 'time': []}, 'Объявленный ВСУ ликвидированным командующий Черноморским флотом дал интервью': {'link': 'https://lenta.ru/news/2023/09/27/chfsh/', 'date': '2023/09/27', 'time': []}, 'Крупнейшая криптовалютная биржа уйдет из России': {'link': 'https://lenta.ru/news/2023/09/27/bin_rus/', 'date': '2023/09/27', 'time': []}, 'В ЛНР рассказали об эвакуации ВСУ раненой «важной персоны» из района Сватово': {'link': 'https://lenta.ru/news/2023/09/27/persona/', 'date': '2023/09/27', 'time': []}, 'На Западе озвучили страшный для Зеленского сценарий по Украине. Реальна ли для страны перспектива раскола на две части?': {'link': 'https://lenta.ru/news/2023/09/27/pais_ukraine/', 'date': '2023/09/27', 'time': []}, 'Гильдия сценаристов Голливуда объявила о завершении забастовки': {'link': 'https://lenta.ru/news/2023/09/27/zabastovka/', 'date': '2023/09/27', 'time': []}, 'Украина попросила у Запада оружие для атак на заводы в Иране': {'link ...

# %%
pprint(response.text)
# Out:
# ('\n'
#  '<!DOCTYPE html>\n'
#  '<html lang="ru" translate="no" class="adaptive">\n'
#  '<head>\n'
#  '    <meta charset="UTF-8">\n'
#  '        <base href="https://www.wildberries.ru/">\n'
#  '    <meta name="format-detection" content="telephone=no">\n'
#  '    <meta name="referrer" content="no-referrer-when-downgrade">\n'
#  '    <meta name="viewport" content="width=device-width, initial-scale=1">\n'
#  '    <meta name="application-name" content="Wildberries" />\n'
#  '    <meta name="yandex-verification" content="61b95d33285e2612" />\n'
#  '    <meta name="google-site-verification" '
#  'content="guMau7oNvBifqUhZGuuGVtiGD0HkKe8v6uwYpvj2ZIg" />\n'
#  "    <meta name='wmail-verification' "
#  "content='e08a4d66746555c8641fe953d12262c8' />\n"
#  '    <meta name="apple-itunes-app" content="app-id=597880187">\n'
#  '    <link rel="manifest" href="/manifestv2.json">\n'
#  '    <link rel="search" type="application/opensearchdescription+xml" '
#  'href="/opensearch.xml" title="test" />\n'
#  '    <link rel="icon" href="/favicon.ico" type="image/vnd.microsoft.icon">\n'
#  '\n'
#  '\n'
#  '    <link rel="preconnect" href="https://static-basket-01.wb.ru">\n'
#  '    <link rel="preconnect" href="https://splitter.wb.ru">\n'
#  '    <link rel="preconnect" href="https://photos.wbstatic.net">\n'
#  '    <link rel="preconnect" href="https://wb.ru"/>\n'
#  '    <link '
#  'href="//static-basket-01.wb.ru/vol0/s/desktop/style/views/spa/main-v3.min.e8ec0c603d2019c9.css" '
#  'rel="stylesheet" type="text/css" />\n'
#  '<link '
#  'href="//static-basket-01.wb.ru/vol0/s/desktop/style/views/spa/common.min.5717ab9180804613.css" '
#  'rel="stylesheet" type="text/css" />\n'
#  '\n'
#  '</head>\n'
#  '<body class="ru">\n'
#  '    \n'
#  '\n'
#  '\n'
#  '    <div class="wrapper">\n'
#  '        \n'
#  "            <header class='header j-header ' >\n"
#  '                <div class="header__container">\n'
#  '                    \n'
#  '\n'
#  '<div class="header__top">\n'
#  '    <ul class="header__simple-menu simple-menu">\n'
#  '        <li class="simple-menu__item j-b-header-country">\n'
#  '            <span class="simple-menu__link simple-menu__link--country '
#  'j-wba-header-item" data-wba-header-name="Country">\n'
#  '                <span class="simple-menu__flag" '
#  'data-link="class{:\'simple-menu__flag\' + (~wbCurrencies[currentCurrency] ? '
#  '\' flag-\' + ~wbCurrencies[currentCurrency].locale : \'\' )}"></span>\n'
#  '                <span class="simple-menu__currency" '
#  'data-link="currentCurrency"></span>\n'
#  '            </span>\n'
#  '            <div class="simple-menu__tooltip tooltip-simple '
#  'tooltip-country">\n'
#  '                <div class="tooltip__content">\n'
#  '                    <div class="country j-country">\n'
#  '                        <div class="country__item '
#  'j-b-change-currency"></div>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '            </div>\n'
#  '        </li>\n'
#  '        <li class="simple-menu__item j-geocity-wrap"><span '
#  'class="simple-menu__link simple-menu__link--address j-geocity-link '
#  'j-wba-header-item" data-wba-header-name="DLV_Adress"></span></li>\n'
#  '        <li class="simple-menu__item hide j-s-vsemrabota"><a '
#  'href="https://vsemrabota.ru/appwb/" target="_blank" rel="noopener" '
#  'class="simple-menu__link j-wba-header-item" '
#  'data-wba-header-name="Vsemrabota">Трудоустройство</a></li>\n'
#  '\n'
#  '        <li class="simple-menu__item"><a '
#  'href="https://seller.wildberries.ru/" class="simple-menu__link '
#  'simple-menu__link--sell-on-wb j-wba-header-item" '
#  'data-wba-header-name="Seller" target="_blank">Продавайте на '
#  'Wildberries</a></li>\n'
#  '\n'
#  '            <li class="simple-menu__item"><a '
#  'href="https://www.wildberries.ru/services/trudoustroystvo" '
#  'class="simple-menu__link simple-menu__link--employment j-wba-header-item" '
#  'data-wba-header-name="Job">Работа в Wildberries</a></li>   \n'
#  '    </ul>\n'
#  '    <a href="/lk/mywallet/purchases" id="balanceBlock" '
#  'class="header__balance" style="display: none" data-link="visible{:balance '
#  '!== undefined}html{priceWithCurrencyV2: balance true iso=\'RUB\'}"></a>\n'
#  '</div>\n'
#  '\n'
#  '<div class="header__bottom">\n'
#  '    <div class="header__nav-element nav-element">\n'
#  '        <button class="nav-element__burger j-menu-burger-btn '
#  'j-wba-header-item hide-mobile" data-wba-header-name="Catalog" type="button" '
#  'aria-label="Навигация по сайту"><span '
#  'class="nav-element__burger-line"></span></button>\n'
#  '        <a class="nav-element__logo j-wba-header-item" '
#  'data-wba-header-name="Main" href="/">\n'
#  '            <img src="//static-basket-01.wb.ru/vol0/i/header/logo-v1.svg" '
#  'width="240" height="64" alt="Wildberries">\n'
#  '        </a>\n'
#  '\n'
#  '        <div class="header__nav-icons">\n'
#  '            <button class="nav-element__currency hide-desktop '
#  'j-currency-show-popup" type="button" aria-label="Выбор валюты">\n'
#  '                <span data-link="class{:\'nav-element__currency-flag flag-\' '
#  '+~wbCurrencies[currentCurrency].locale}"></span>\n'
#  '                <span data-link="currentCurrency"></span>\n'
#  '            </button>\n'
#  '            <button class="nav-element__geo hide-desktop j-geocity-link '
#  'j-wba-header-item" data-wba-header-name="DLV_Adress" type="button" '
#  'aria-label="Ваше местоположение"></button>\n'
#  '            <button class="nav-element__search j-search-header-icon '
#  'hide-desktop j-wba-header-item" data-wba-header-name="Search_text" '
#  'type="button" aria-label="Поиск"></button>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '    <div class="header__navbar-pc navbar-pc j-b-header-menu" '
#  'id="basketContent">\n'
#  '        <div class="navbar-pc__item">\n'
#  '            <a class="navbar-pc__link j-wba-header-item" '
#  'data-wba-header-name="Cart" href="/lk/basket">\n'
#  '                <span class="navbar-pc__icon '
#  'navbar-pc__icon--basket"></span>\n'
#  '                Корзина\n'
#  '            </a>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '    <div id="searchBlock" class=\'header__search-catalog search-catalog '
#  "j-search-catalog hide-mobile ' \n"
#  '         data-link="\n'
#  "         {on 'click' '.j-suggest' followSuggest}\n"
#  "         {on 'click' '.j-suggest-tag' fillWithTag}\n"
#  "         {on 'click' '.j-clear-history-all' clearAllSearchHistories}\n"
#  "         {on 'click' '.j-clear-history' clearSearchHistory}\n"
#  "         {on 'mouseover' '.j-suggest' markSuggest}\n"
#  "         {on 'mouseleave' '.j-search-catalog-autocomplete' unmarkSuggests}\n"
#  '         class{merge: imageChipData toggle=\'search-catalog--photo\'}">\n'
#  '\n'
#  '<div class="search-catalog__block" data-link="class{merge: '
#  'hasAnySuggestions() toggle=\'search-catalog--active\'}">\n'
#  '    <input autocomplete="off" id="searchInput" class="search-catalog__input '
#  'j-wba-header-item" data-wba-header-name="Search_text" type="search" '
#  'maxlength="300" placeholder="Я ищу..."\n'
#  '           data-link="{:searchText:}readonly{:imageChipData}{on \'keydown\' '
#  "onSearchInputKeypress}{on 'focus' enableSuggestions}{on 'input' "
#  'showSuggestionsDebounced}">\n'
#  '    <div class="search-catalog__loading" data-link="{include imageChipData '
#  'tmpl=(imageChipData && imageChipData.template)}"></div>\n'
#  '\n'
#  '    <button id="applySearchBtn" class="search-catalog__btn '
#  'search-catalog__btn--search" type="button" data-link="{on applySearch}">\n'
#  '        Поиск товара\n'
#  '    </button>\n'
#  '\n'
#  '    <div class="search-catalog__btn-wrap">\n'
#  '        <button class="search-catalog__btn search-catalog__btn--clear" '
#  'type="button" \n'
#  '                data-link="class{merge: searchText '
#  'toggle=\'search-catalog__btn--active\'}{on clearSearch}">Очистить '
#  'поиск</button>\n'
#  '\n'
#  '        <div id="searchByImageContainer" class="search-catalog__photo" '
#  'data-link="class{merge: showImageSearch '
#  'toggle=\'search-catalog__photo--active\'}">\n'
#  '            <button class="search-catalog__btn search-catalog__btn--photo '
#  'j-search-img-btn j-wba-header-item" data-wba-header-name="Search_photo" '
#  'type="button" data-link="{on toggleProperty \'showImageSearch\'}">\n'
#  '                Поиск по фото\n'
#  '            </button>\n'
#  '            <div id="searchByImageBtn" class="search-catalog__photo-tooltip '
#  'tooltip-simple tooltip-search-photo">\n'
#  '                <div class="tooltip__content">Поиск по фото</div>\n'
#  '            </div>\n'
#  '            <form id="searchByImageForm" '
#  'class="search-catalog__upload-tooltip tooltip-simple tooltip-upload-photo" '
#  'action="/search/image" method="post" enctype="multipart/form-data" '
#  'data-link="class{merge: uploadingPhoto '
#  'toggle=\'tooltip-upload-photo--loading\'}">\n'
#  '                <div class="tooltip__content">\n'
#  '                    <label class="upload-photo-btn" data-link="class{merge: '
#  'uploadingPhoto toggle=\'progress\'}">\n'
#  '                        Выберите файл\n'
#  '                        <input data-link="{on \'change\' searchByImage}" '
#  'type="file" accept="image/*" name="photo">\n'
#  '                    </label>\n'
#  '                    <div class="upload-photo-text">\n'
#  '                        <p class="upload-photo-text__item">Максимальный '
#  'размер: <span>8 МБ.</span></p>\n'
#  '                        <p class="upload-photo-text__item">Поддерживаемые '
#  'форматы: <span>JPG, JPEG, PNG, BMP,&nbsp;GIF.</span></p>\n'
#  '\n'
#  '                        <p class="upload-photo-text__item '
#  'upload-photo-text__item--message">Загрузка файла</p>\n'
#  '                    </div>\n'
#  '                </div>\n'
#  '            </form>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '<div class="autocomplete search-catalog__autocomplete '
#  'j-search-catalog-autocomplete" data-link="{if hasAnySuggestions() '
#  'tmpl=\'searchSuggestionsTmpl\'}"></div>    </div>\n'
#  '</div>\n'
#  '\n'
#  '                </div>\n'
#  '            </header>\n'
#  '        \n'
#  '        \n'
#  '\n'
#  '\n'
#  '\n'
#  '<div class="menu-burger j-menu-burger"\n'
#  '     data-link="\n'
#  "     {on 'mousedown click' '.j-menu-main-item' ~wbSettings^displayMode=='d' "
#  '? ~root.$void : ~root.menuSelectedHandler}\n'
#  "     {on 'click' '.j-menu-burger-mobile-back' ~wbSettings^displayMode=='d' ? "
#  '~root.$void : ~root.backLinkHandler}\n'
#  "     {on 'click' '.j-menu-drop-list-item-subcategory' "
#  "~wbSettings^displayMode=='d' ? ~root.$void : ~root.categorySelectHandler}\n"
#  "     {on 'click' '.j-menu-selected-category' ~root.selectedCategoryClicked}\n"
#  "     {on 'click' '.j-menu-main-item a' ~root.sendClickMenuLinkEvent}\n"
#  "     {on 'click' '.j-menu-drop-link' ~root.sendClickMenuLinkEvent}\n"
#  "     {on 'click' '.j-deny-link' ~root.onDenyLinksClicked}\n"
#  "     {on 'click' '.j-banner-wba' ~root.sendClickMenuBannerEvent}\n"
#  "     {on 'click' '.j-tecdoc-search-menu' ~root.tecDocSearchOpen}\n"
#  "     {on 'click' '.j-menu-drop-open' ~root.menuDropItemOpen}\n"
#  "     {on 'click' '.j-menu-premium-brand-link' ~root.moveToBrand}\n"
#  '     ">\n'
#  '    <div class="menu-burger__mobile-header hide-desktop">\n'
#  '        <input class="menu-burger__btn-search j-search-input-mobile" '
#  'type="search" placeholder="Я ищу..." />\n'
#  '    </div>\n'
#  '    <div class="menu-burger__main j-menu-burger-main">\n'
#  '\n'
#  '                    \n'
#  '\n'
#  '<ul class="menu-burger__main-list">\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="306">\n'
#  '        <a href="https://www.wildberries.ru/catalog/zhenshchinam" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--306">Женщинам</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="629">\n'
#  '        <a href="https://www.wildberries.ru/catalog/obuv" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--629">Обувь</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="115">\n'
#  '        <a href="https://www.wildberries.ru/catalog/detyam" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--115">Детям</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="566">\n'
#  '        <a href="https://www.wildberries.ru/catalog/muzhchinam" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--566">Мужчинам</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="258">\n'
#  '        <a href="https://www.wildberries.ru/catalog/dom-i-dacha" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--258">Дом</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="543">\n'
#  '        <a href="https://www.wildberries.ru/catalog/krasota" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--543">Красота</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="1">\n'
#  '        <a href="https://www.wildberries.ru/catalog/aksessuary" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--1">Аксессуары</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="4830">\n'
#  '        <a href="https://www.wildberries.ru/catalog/elektronika" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--4830">Электроника</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="481">\n'
#  '        <a href="https://www.wildberries.ru/catalog/igrushki" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--481">Игрушки</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="62827">\n'
#  '        <a href="https://www.wildberries.ru/catalog/dom/mebel" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--62827">Мебель</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="62057">\n'
#  '        <a '
#  'href="https://www.wildberries.ru/catalog/aksessuary/tovary-dlya-vzroslyh" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--62057">Товары для взрослых</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="10296">\n'
#  '        <a href="https://www.wildberries.ru/catalog/pitanie" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--10296">Продукты</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="16107">\n'
#  '        <a href="https://www.wildberries.ru/catalog/bytovaya-tehnika" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--16107">Бытовая техника</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="6119">\n'
#  '        <a href="https://www.wildberries.ru/catalog/tovary-dlya-zhivotnyh" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--6119">Зоотовары</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="784">\n'
#  '        <a href="https://www.wildberries.ru/catalog/sport" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--784">Спорт</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="6994">\n'
#  '        <a href="https://www.wildberries.ru/catalog/aksessuary/avtotovary" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--6994">Автотовары</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="519">\n'
#  '        <a href="https://www.wildberries.ru/catalog/knigi" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--519">Книги</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="128297">\n'
#  '        <a href="https://www.wildberries.ru/catalog/premium-store" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--128297">Premium</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="1023">\n'
#  '        <a href="https://www.wildberries.ru/catalog/yuvelirnye-ukrasheniya" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--1023">Ювелирные изделия</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="17006">\n'
#  '        <a href="https://www.wildberries.ru/catalog/dom-i-dacha/instrumenty" '
#  'class="menu-burger__main-list-link menu-burger__main-list-link--17006">Для '
#  'ремонта</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="4863">\n'
#  '        <a href="https://www.wildberries.ru/catalog/dachniy-sezon" '
#  'class="menu-burger__main-list-link menu-burger__main-list-link--4863">Сад и '
#  'дача</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="10326">\n'
#  '        <a href="https://www.wildberries.ru/catalog/dom-i-dacha/zdorove" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--10326">Здоровье</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="5486">\n'
#  '        <a '
#  'href="https://www.wildberries.ru/catalog/knigi-i-diski/kantstovary" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--5486">Канцтовары</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="12">\n'
#  '        <a href="https://digital.wildberries.ru/" '
#  'class="menu-burger__main-list-link menu-burger__main-list-link--12">Цифровые '
#  'товары</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="2192">\n'
#  '        <a href="https://www.wildberries.ru/promotions" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--2192">Акции</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="130255">\n'
#  '        <a href="https://www.wildberries.ru/catalog/sdelano-v-moskve" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--130255">Сделано в Москве</a>\n'
#  '    </li>\n'
#  '    <li class="menu-burger__main-list-item j-menu-main-item " '
#  'data-menu-id="61037">\n'
#  '        <a href="https://vmeste.wildberries.ru/" '
#  'class="menu-burger__main-list-link '
#  'menu-burger__main-list-link--61037">Путешествия</a>\n'
#  '    </li>\n'
#  '</ul>\n'
#  '\n'
#  '        <div class="menu-burger__geo">\n'
#  '            <div class="menu-burger__geo-item menu-burger__geo-item--city '
#  'j-geocity-link"></div>\n'
#  '        </div>\n'
#  '\n'
#  '    </div>\n'
#  '    <div class="menu-burger__drop j-menu-burger-drop" data-link="\n'
#  "         {for #data tmpl='menuInnerTmpl'}\n"
#  '         class{merge: ~root^selectedMenuItem && '
#  '~root^selectedMenuItem.childs || ~root^selectedMenuItem && '
#  "~root^selectedMenuItem.banners toggle='menu-burger__drop--active "
#  "j-menu-active'}\n"
#  '         class{merge: ~root^selectedMenuItem && '
#  '~root.isCommonMenuItem(~root^selectedMenuItem.id) '
#  "toggle='menu-burger__drop--custom'}\n"
#  '         "></div>\n'
#  '    <button class="menu-burger__close j-close-menu-mobile hide-mobile" '
#  'type="button">Закрыть меню</button>\n'
#  '</div>\n'
#  '        \n'
#  '\n'
#  '        <main class="main left-bg" role="main" id="body-layout">\n'
#  '            \n'
#  '    <div class="lk-menu">\n'
#  '        <div class="lk-menu__container j-lk-menu-top hide">\n'
#  '\n'
#  '\n'
#  '    <div class="lk-menu-main hide-mobile">\n'
#  '        <ul class="lk-menu-main__content">\n'
#  '            <li class="lk-menu-main__item lk-menu-main__item--main-page">\n'
#  '                <a href="/lk" class="lk-menu-main__title" '
#  'data-main="true">Главная</a>\n'
#  '            </li>\n'
#  '            <li class="lk-menu-main__item lk-menu-main__item--favorites" '
#  'data-attr="1">\n'
#  '                <a href="/lk/favorites" class="lk-menu-main__title" '
#  'data-main="true" data-lk-header-wba="LK_Header_Favorites">Избранное</a>\n'
#  '                <div class="lk-menu-main__sub">\n'
#  '                    <ul class="lk-menu-main__sub-list" data-attr="1">\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/favorites" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_Favorites">Избранное</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/favoritebrands" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="Favourite_Brand">Любимые бренды</a>\n'
#  '                        </li>\n'
#  '                    </ul>\n'
#  '                </div>\n'
#  '            </li>\n'
#  '            <li id="menuTooltipTarget" class="lk-menu-main__item '
#  'lk-menu-main__item--orders" data-attr="2">\n'
#  '                <a href="/lk/myorders/delivery" class="lk-menu-main__title" '
#  'data-main="true" data-lk-header-wba="LK_Header_Purchases">Покупки</a>\n'
#  '                <div class="lk-menu-main__sub">\n'
#  '                    <ul class="lk-menu-main__sub-list" data-attr="2">\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/myorders/delivery" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_DLV">Доставки</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/myorders/archive" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_Purchases">Покупки</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item hide" '
#  'data-switch="customerReceipt">\n'
#  '                            <a href="/lk/receipts/get?count=10" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_eCheck">Чеки</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item hide" '
#  'data-switch="enableMyRefunds">\n'
#  '                            <a href="/lk/myrefunds" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_Refunds">Возвраты</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item hide" '
#  'data-switch="enableRefund">\n'
#  '                            <a href="/lk/refund" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_RefundRegistration">Оформление возврата</a>\n'
#  '                        </li>\n'
#  '                    </ul>\n'
#  '                </div>\n'
#  '            </li>\n'
#  '                <li class="lk-menu-main__item lk-menu-main__item--travel" '
#  'data-attr="7">\n'
#  '                    <a href="/lk/travel" class="lk-menu-main__title" '
#  'data-main="true">Travel</a>\n'
#  '                </li>\n'
#  '            <li class="lk-menu-main__item lk-menu-main__item--feedback" '
#  'data-attr="3">\n'
#  '                <a href="/lk/communications" class="lk-menu-main__title" '
#  'data-main="true" data-lk-header-wba="LK_Header_Requests">Обращения</a>\n'
#  '                <div class="lk-menu-main__sub">\n'
#  '                    <ul class="lk-menu-main__sub-list" data-attr="3">\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/communications" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_Requests">Обращения</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item hide" '
#  'data-switch="enableClaims">\n'
#  '                            <a href="/lk/claims" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_ItemExamination">Проверка товара</a>\n'
#  '                        </li>\n'
#  '                    </ul>\n'
#  '                </div>\n'
#  '            </li>\n'
#  '            <li class="lk-menu-main__item lk-menu-main__item--social" '
#  'data-attr="4">\n'
#  '                <a href="/lk/discussion/feedback?type=Comments" '
#  'class="lk-menu-main__title" data-main="true" '
#  'data-lk-header-wba="LK_Header_Feedback">Отзывы и вопросы</a>\n'
#  '                <div class="lk-menu-main__sub">\n'
#  '                    <ul class="lk-menu-main__sub-list">\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/discussion/feedback?type=Comments" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_Feedback">Отзывы</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/discussion/feedback?type=Questions" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_ItemQuestions">Вопросы</a>\n'
#  '                        </li>\n'
#  '                    </ul>\n'
#  '                </div>\n'
#  '            </li>\n'
#  '                <li class="lk-menu-main__item lk-menu-main__item--balance '
#  'hide" data-attr="6" data-switch="showWallet">\n'
#  '                    <a href="/lk/mywallet/purchases" '
#  'class="lk-menu-main__title" data-main="true">Баланс</a>\n'
#  '                </li>\n'
#  '            <li class="lk-menu-main__item lk-menu-main__item--profile" '
#  'data-attr="5">\n'
#  '                <a href="/lk/details" class="lk-menu-main__title" '
#  'data-main="true">Профиль</a>\n'
#  '                <div class="lk-menu-main__sub lk-menu-main__sub--right">\n'
#  '                    <ul class="lk-menu-main__sub-list" data-attr="5">\n'
#  '                        <li class="lk-menu-main__sub-item">\n'
#  '                            <a href="/lk/details" '
#  'class="lk-menu-main__sub-link" data-main="false">Личные данные</a>\n'
#  '                        </li>\n'
#  '                        <li class="lk-menu-main__sub-item hide" '
#  'data-switch="apiShowEvents">\n'
#  '                            <a href="/lk/newsfeed/events" '
#  'class="lk-menu-main__sub-link" data-main="false" '
#  'data-lk-header-wba="LK_Notifications">Уведомления</a>\n'
#  '                        </li>\n'
#  '                    </ul>\n'
#  '                </div>\n'
#  '            </li>\n'
#  '        </ul>\n'
#  '    </div>\n'
#  '\n'
#  '    <div class="lk-menu-sub">\n'
#  '        <div class="lk-menu-sub__wrapper">\n'
#  '            <ul class="lk-menu-sub__list" data-attr="1">\n'
#  '                <li data-id="33">\n'
#  '                    <a href="/lk/favorites" data-main="false" '
#  'data-sub="true" data-lk-header-wba="LK_Favorites">Избранное</a>\n'
#  '                </li>\n'
#  '                <li data-id="19">\n'
#  '                    <a href="/lk/favoritebrands" data-main="false" '
#  'data-sub="true" data-lk-header-wba="Favourite_Brand">Любимые бренды</a>\n'
#  '                </li>\n'
#  '            </ul>\n'
#  '            <ul class="lk-menu-sub__list" data-attr="2">\n'
#  '                <li data-id="6">\n'
#  '                    <a href="/lk/myorders/delivery" data-main="false" '
#  'data-sub="true" data-lk-header-wba="LK_DLV">Доставки</a>\n'
#  '                </li>\n'
#  '                <li data-id="4">\n'
#  '                    <a href="/lk/myorders/archive" data-main="false" '
#  'data-sub="true" data-lk-header-wba="LK_Purchases">Покупки</a>\n'
#  '                </li>\n'
#  '                <li data-id="28" class="hide" '
#  'data-switch="customerReceipt">\n'
#  '                    <a href="/lk/receipts/get?count=10" data-main="false" '
#  'data-sub="true" data-lk-header-wba="LK_eCheck">Чеки</a>\n'
#  '                </li>\n'
#  '                <li data-id="8" class="hide" data-switch="enableMyRefunds">\n'
#  '                    <a href="/lk/myrefunds" data-main="false" '
#  'data-sub="true" data-lk-header-wba="LK_Refunds">Возвраты</a>\n'
#  '                </li>\n'
#  '                <li data-id="10" class="hide" data-switch="enableRefund">\n'
#  '                    <a href="/lk/refund" data-main="false" data-sub="true" '
#  'data-lk-header-wba="LK_RefundRegistration">Оформление возврата</a>\n'
#  '                </li>\n'
#  '            </ul>\n'
#  '            <ul class="lk-menu-sub__list" data-attr="3">\n'
#  '                <li data-id="16">\n'
#  '                    <a href="/lk/communications" data-main="false" '
#  'data-sub="true" data-lk-header-wba="LK_Requests">Обращения</a>\n'
#  '                </li>\n'
#  '                <li data-id="26" class="hide" data-switch="enableClaims">\n'
#  '                    <a href="/lk/claims" data-main="false" data-sub="true" '
#  'data-lk-header-wba="LK_ItemExamination">Проверка товара</a>\n'
#  '                </li>\n'
#  '            </ul>\n'
#  '            <ul class="lk-menu-sub__list" data-attr="5">\n'
#  '                <li data-id="13">\n'
#  '                    <a href="/lk/details" data-main="false" '
#  'data-sub="true">Личные данные</a>\n'
#  '                </li>\n'
#  '                <li data-id="14" data-switch="apiShowEvents" class="hide">\n'
#  '                    <a href="/lk/newsfeed/events" data-main="false" '
#  'data-sub="true" data-lk-header-wba="LK_Notifications">Уведомления</a>\n'
#  '                </li>\n'
#  '            </ul>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '\n'
#  '        </div>\n'
#  '    </div>\n'
#  '\n'
#  '            <div id="mainContainer" class="main__container">\n'
#  '                \n'
#  '\n'
#  '    <div id="app">\n'
#  '            <div class="general-preloader"></div>\n'
#  '    </div>\n'
#  '\n'
#  '<button class="btn-quick-nav j-quicknav" type="button">К началу '
#  'страницы</button>\n'
#  '\n'
#  '\n'
#  '            </div>\n'
#  '            \n'
#  '        </main>\n'
#  '\n'
#  '        \n'
#  '            \n'
#  '<footer class="footer j-footer footer-ru" id="footer"\n'
#  '        data-link="\n'
#  "        {on 'click' '.j-dropdown-title' ~root.onMenuSelected}\n"
#  '        {on \'click\' \'.j-wba-footer-item\' ~root.sendStatEvent}">\n'
#  '    <div class="footer__container">\n'
#  '        <div class="footer__nav">\n'
#  '            <div class="footer__service-wrap j-dropdown-footer">\n'
#  '                <section class="footer__list-wrap '
#  'footer__list-wrap--buyers">\n'
#  '                    <div class="footer__header-wrap j-dropdown-title">\n'
#  '                        <h2 class="footer__header">Покупателям</h2>\n'
#  '                        <button class="footer__btn-open" '
#  'type="button">Открыть</button>\n'
#  '                    </div>\n'
#  '                    <ul class="footer__list footer__list--dropdown">\n'
#  '                            <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="How_to_order"><a rel="nofollow" '
#  'href="/services/kak-sdelat-zakaz">Как сделать заказ</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Pay_methods"><a rel="nofollow" '
#  'href="/services/sposoby-oplaty">Способы оплаты</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Delivery"><a rel="nofollow" '
#  'href="/services/besplatnaya-dostavka">Доставка</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Return_order"><a rel="nofollow" '
#  'href="/services/vozvrat-tovara">Возврат товара</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Refunds"><a rel="nofollow" '
#  'href="/services/vozvrat-denezhnyh-sredstv">Возврат денежных '
#  'средств</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Sale_policy"><a rel="nofollow" '
#  'href="/services/pravila-prodazhi">Правила продажи</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Store_policy"><a rel="nofollow" '
#  'href="/services/pravila-polzovaniya-torgovoy-ploshchadkoy" '
#  'data-link="text{:~wbSettings.currentLocale == \'ru\' ? \'Правила пользования '
#  'торговой площадкой\' : \'Публичная оферта\'}"></a></li>\n'
#  '                            <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Questions"><a rel="nofollow" '
#  'href="/services/voprosy-i-otvety">Вопросы и ответы</a></li>\n'
#  '                    </ul>\n'
#  '                </section>\n'
#  '\n'
#  '                <div class="footer__inner-wrap">\n'
#  '                    <section class="footer__list-wrap">\n'
#  '                        <div class="footer__header-wrap j-dropdown-title">\n'
#  '                            <h2 class="footer__header">Партнерам</h2>\n'
#  '                            <button class="footer__btn-open" '
#  'type="button">Открыть</button>\n'
#  '                        </div>\n'
#  '                        <ul class="footer__list footer__list--dropdown">\n'
#  '                            <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Seller"><a rel="nofollow" target="_blank" '
#  'href="https://seller.wildberries.ru/">Продавайте на Wildberries</a></li>\n'
#  '\n'
#  '                                <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="For_couriers"><a rel="nofollow" target="_blank" '
#  'href="https://orr.wildberries.ru/courier-info/index.html">Курьерам</a></li>\n'
#  '                                <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Carrier"><a rel="nofollow" target="_blank" '
#  'href="/promo/priglashaem-k-sotrudnichestvu">Перевозчикам</a></li>\n'
#  '\n'
#  '                                <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Pick_up_points_open"><a rel="nofollow" target="_blank" '
#  'href="https://point-promo.wb.ru/">Партнерский пункт выдачи</a></li>\n'
#  '\n'
#  '                                <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Franchise"><a rel="nofollow" target="_blank" '
#  'href="/services/franshizniy-punkt-vydachi">Франшизный пункт выдачи</a></li>\n'
#  '                        </ul>\n'
#  '                    </section>\n'
#  '\n'
#  '                    <section class="footer__list-wrap">\n'
#  '                        <div class="footer__header-wrap j-dropdown-title">\n'
#  '                            <h2 class="footer__header">Наши проекты</h2>\n'
#  '                            <button class="footer__btn-open" '
#  'type="button">Открыть</button>\n'
#  '                        </div>\n'
#  '                        <ul class="footer__list footer__list--dropdown">\n'
#  '                            <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Guru"><a rel="nofollow" target="_blank" '
#  'href="https://guru.wildberries.ru/?utm_source=main_footer">WB Guru</a></li>\n'
#  '                                <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Job"><a rel="nofollow" target="_blank" '
#  'href="https://vsemrabota.ru/appwb/">Трудоустройство</a></li>\n'
#  '                                <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Digital"><a rel="nofollow" target="_blank" '
#  'href="https://digital.wildberries.ru/">Цифровые товары</a></li>\n'
#  '                            <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Travel"><a rel="nofollow" target="_blank" '
#  'href="https://vmeste.wildberries.ru/">WB Путешествия</a></li>\n'
#  '                                <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Stream"><a rel="nofollow" target="_blank" '
#  'href="/promo/wb-stream">WB Stream</a></li>\n'
#  '                        </ul>\n'
#  '                    </section>\n'
#  '                </div>\n'
#  '\n'
#  '                <section class="footer__list-wrap '
#  'footer__list-wrap--company">\n'
#  '                    <div class="footer__header-wrap j-dropdown-title">\n'
#  '                        <h2 class="footer__header">Компания</h2>\n'
#  '                        <button class="footer__btn-open" '
#  'type="button">Открыть</button>\n'
#  '                    </div>\n'
#  '                    <ul class="footer__list footer__list--dropdown">\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="About_us"><a rel="nofollow" href="/services/o-nas">О '
#  'нас</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Bank_info"><a rel="nofollow" '
#  'href="/services/rekvizity">Реквизиты</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Press"><a rel="nofollow" '
#  'href="/presscenter">Пресс-центр</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Сontacts"><a rel="nofollow" '
#  'href="/services/kontakty">Контакты</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Bug_Bounty"><a rel="nofollow" '
#  'href="/services/bug-bounty">Bug Bounty</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="WB_Tech"><a target="_blank" rel="nofollow" '
#  'href="https://t.me/wb_tech">WB.Tech</a></li>\n'
#  '                    </ul>\n'
#  '                </section>\n'
#  '\n'
#  '                <section class="footer__list-wrap '
#  'footer__list-wrap--social">\n'
#  '                    <div class="footer__header-wrap j-dropdown-title">\n'
#  '                        <h2 class="footer__header">Мы в соцсетях</h2>\n'
#  '                        <button class="footer__btn-open" '
#  'type="button">Открыть</button>\n'
#  '                    </div>\n'
#  '                    <ul class="footer__list footer__list--dropdown">\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Vk"><a rel="nofollow noopener" target="_blank" '
#  'href="http://vk.com/club9695053">ВКонтакте</a></li>\n'
#  '\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="Ok"><a rel="nofollow noopener" target="_blank" '
#  'href="http://www.odnoklassniki.ru/wildberries">Одноклассники</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="YouTube"><a rel="nofollow noopener" target="_blank" '
#  'href="https://www.youtube.com/Wildberriesshop">YouTube</a></li>\n'
#  '                        <li class="footer__item"><a rel="nofollow noopener" '
#  'target="_blank" '
#  'href="https://t.me/wildberriesru_official">Телеграм</a></li>\n'
#  '                    </ul>\n'
#  '                </section>\n'
#  '            </div>\n'
#  '\n'
#  '            <div class="footer__social-wrap">\n'
#  '                <section class="footer__list-wrap '
#  'footer__list-wrap--download">\n'
#  '                    <h2 class="footer__header">Приложение Wildberries</h2>\n'
#  '                    <ul class="footer__list hide-desktop">\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="GooglePlay"><a class="google-play" rel="nofollow '
#  'noopener" target="_blank" '
#  'href="https://play.google.com/store/apps/details?id=com.wildberries.ru">Загрузить '
#  'из Google Play</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="AppStore"><a class="app-store" rel="nofollow noopener" '
#  'target="_blank" '
#  'href="https://apps.apple.com/ru/app/wildberries/id597880187">Загрузить из '
#  'AppStore</a></li>\n'
#  '                        <li class="footer__item j-wba-footer-item" '
#  'data-wba-footer-name="AppGallery"><a class="app-gallery" rel="nofollow '
#  'noopener" target="_blank" '
#  'href="https://appgallery8.huawei.com/#/app/C101183325">Загрузить из '
#  'AppGallery</a></li>\n'
#  '                    </ul>\n'
#  '                    <div class="footer__apps footer-apps hide-mobile">\n'
#  '                        <img class="footer-apps__img" '
#  'src="//static-basket-01.wb.ru/vol0/i/v3/apps/qr.png" width="136" '
#  'height="136" alt="qr-code">\n'
#  '                        <p class="footer-apps__text">Наведите камеру, чтобы '
#  'скачать приложение</p>\n'
#  '                        <ul class="footer-apps__list">\n'
#  '                            <li class="footer-apps__item">\n'
#  '                                <a class="footer-apps__icon '
#  'footer-apps__icon--ios" rel="nofollow noopener" target="_blank" '
#  'href="https://apps.apple.com/ru/app/wildberries/id597880187">Загрузить из '
#  'AppStore</a>\n'
#  '                            </li>\n'
#  '                            <li class="footer-apps__item">\n'
#  '                                <a class="footer-apps__icon '
#  'footer-apps__icon--android" rel="nofollow noopener" target="_blank" '
#  'href="https://play.google.com/store/apps/details?id=com.wildberries.ru">Загрузить '
#  'из Google Play</a>\n'
#  '                            </li>\n'
#  '                            <li class="footer-apps__item">\n'
#  '                                <a class="footer-apps__icon '
#  'footer-apps__icon--huawei" rel="nofollow noopener" target="_blank" '
#  'href="https://appgallery8.huawei.com/#/app/C101183325">Загрузить из '
#  'AppGallery</a>\n'
#  '                            </li>\n'
#  '                        </ul>\n'
#  '                    </div>\n'
#  '                </section>\n'
#  '\n'
#  '                <p class="footer__copyrights hide-desktop">\n'
#  '\n'
#  '\n'
#  '<span>2004-2023 &copy; Wildberries</span><span class="hide-mobile"> — модный '
#  'интернет-магазин одежды, обуви и аксессуаров. Все права защищены.</span>\n'
#  '    <span class="hide-mobile">Доставка по всей России.</span>\n'
#  '                </p>\n'
#  '            </div>\n'
#  '        </div>\n'
#  '\n'
#  '            <div class="footer__add-info hide-mobile">\n'
#  '                    <div class="footer__compatability">\n'
#  '                        <a rel="nofollow" class="j-wba-footer-item" '
#  'data-wba-footer-name="Сompatibility" '
#  'href="/services/proverka-sovmestimosti">Проверка совместимости</a>\n'
#  '                    </div>\n'
#  '\n'
#  '                <p class="footer__copyrights">\n'
#  '\n'
#  '\n'
#  '<span>2004-2023 &copy; Wildberries</span><span class="hide-mobile"> — модный '
#  'интернет-магазин одежды, обуви и аксессуаров. Все права защищены.</span>\n'
#  '    <span class="hide-mobile">Доставка по всей России.</span>\n'
#  '                </p>\n'
#  '            </div>\n'
#  '    </div>\n'
#  '</footer>\n'
#  '        \n'
#  '    </div>\n'
#  '\n'
#  '    \n'
#  '        <div class="navbar-mobile hide-desktop j-navbar-mobile" '
#  'data-link="{on \'click\' \'.navbar-mobile__link\' ~sendAnalytics}">\n'
#  '            <a class="navbar-mobile__link" '
#  'data-wba-header-name="Main_tabbar" data-link-type="home" href="/" '
#  'aria-label="Главная страница">\n'
#  '                <span class="navbar-mobile__icon navbar-mobile__icon--home" '
#  'data-link="class{merge:type == \'home\' '
#  'toggle=\'navbar-mobile__icon--active\'}"></span>\n'
#  '            </a>\n'
#  '            <div class="navbar-mobile__wrap">\n'
#  '                <button id="catalogNavbarLink" class="navbar-mobile__link" '
#  'data-wba-header-name="Catalog_tabbar" data-link-type="catalog" '
#  'aria-label="Каталог" type="button">\n'
#  '                    <span class="navbar-mobile__icon '
#  'navbar-mobile__icon--catalog" data-link="class{merge:catalogState '
#  'toggle=\'navbar-mobile__icon--active\'}"></span>\n'
#  '                </button>\n'
#  '            </div>\n'
#  '            <a class="navbar-mobile__link" '
#  'data-wba-header-name="Cart_tabbar" href="/lk/basket" aria-label="Корзина">\n'
#  '            <span class="navbar-mobile__icon navbar-mobile__icon--basket" '
#  'data-link="class{merge:type == \'basket\' '
#  'toggle=\'navbar-mobile__icon--active\'}">\n'
#  '                <span class="navbar-mobile__notify hide" '
#  'data-link="{:basketCount}class{merge:!basketCount toggle=\'hide\'}"></span>\n'
#  '            </span>\n'
#  '            </a>\n'
#  '            <a class="navbar-mobile__link" '
#  'data-wba-header-name="Favorites_tabbar" href="/lk/favorites" '
#  'aria-label="Избранные товары">\n'
#  '                <span class="navbar-mobile__icon '
#  'navbar-mobile__icon--favorites" data-link="class{merge:type == \'poned\' '
#  'toggle=\'navbar-mobile__icon--active\'}"></span>\n'
#  '            </a>\n'
#  '            <a class="navbar-mobile__link" data-wba-header-name="LK_tabbar" '
#  'href="/lk" aria-label="Личный кабинет">\n'
#  '                <span class="navbar-mobile__icon '
#  'navbar-mobile__icon--profile" data-link="class{merge:type == \'profile\' '
#  'toggle=\'navbar-mobile__icon--active\'}">\n'
#  '                    <span class="navbar-mobile__notify hide" '
#  'data-link="{:(eventsModel && '
#  'eventsModel^eventsCount)}class{merge:!(eventsModel && '
#  'eventsModel^eventsCount) toggle=\'hide\'}"></span>\n'
#  '                </span>\n'
#  '            </a>\n'
#  '        </div>\n'
#  '\n'
#  '        <div class="popup popup-country j-popup-country">\n'
#  '            <button class="popup__close close" '
#  'type="button">Закрыть</button>\n'
#  '            <div class="popup__content"></div>\n'
#  '        </div>\n'
#  '\n'
#  '        <!--noindex-->\n'
#  '        <div class="smm-fixed">\n'
#  '    <button class="smm-fixed__toggle j-btn-chat-open hide" type="button" '
#  'aria-label="Онлайн чат"></button>\n'
#  '</div>\n'
#  '\n'
#  '<div class="j-chat-wrap hide"></div>\n'
#  '        <!--/noindex-->\n'
#  '        <div class="jqmPopWindow update-browser-popup"></div>\n'
#  '    \n'
#  '\n'
#  '    <script '
#  'src="//static-basket-01.wb.ru/vol0/j/app.min.751e846987147bf6.js" '
#  'type="text/javascript"></script>\n'
#  '<script '
#  'src="//static-basket-01.wb.ru/vol0/j/spa/polyfills.min.eb055cd8d54b57cb.js" '
#  'type="text/javascript" nomodule></script>\n'
#  '<script '
#  'src="//static-basket-01.wb.ru/vol0/j/spa/index.min.787ac5ed32f77e22.js" '
#  'type="text/javascript"></script>\n'
#  '\n'
#  '    \n'
#  '        \n'
#  '\n'
#  '<script>\n'
#  'wb.settings = {};\n'
#  '</script>\n'
#  '<script>\n'
#  '        wb.settings = {\n'
#  '            displayMode: "d",\n'
#  '            breakponts: {\n'
#  '                1024: "m" //от 1024 - десктоп\n'
#  '            },\n'
#  '            isIE: navigator.userAgent.indexOf("MSIE ") > 0 || '
#  'navigator.userAgent.indexOf("Trident/") > 0,\n'
#  '            regexp: {\n'
#  "                escapingRegExp: new RegExp('(\\\\' + ['/', '.', '*', '+', "
#  "'?', '|', '(', ')', '[', ']', '{', '}', '\\\\', '$', '^', "
#  '\'"\', "\'"].join(\'|\\\\\') + \')\', \'g\')\n'
#  '            },\n'
#  '            scripts: {\n'
#  '                 browser: '
#  "'//static-basket-01.wb.ru/vol0/j/browser.min.09674cd3d8a80819.js',\n"
#  '                 spaRecommendationCarousel: '
#  "'//static-basket-01.wb.ru/vol0/j/spa/customTags/spa.recommendations.min.d156751f6fbbbdc7.js'\n"
#  '            },\n'
#  '            styles: {\n'
#  '                error500: '
#  "'//static-basket-01.wb.ru/vol0/s/desktop/style/views/site/error500-v3.min.d05a8db968c0a533.css',\n"
#  '                menuBurger: '
#  "'//static-basket-01.wb.ru/vol0/s/desktop/style/modules/menuBurger.min.53fa9e7d17cec4bc.css',\n"
#  '                geo: {\n'
#  '                    geoCity: '
#  "'//static-basket-01.wb.ru/vol0/s/desktop/style/modules/geoBlock.min.863be454b250cc4f.css'\n"
#  '                },\n'
#  '            },\n'
#  '            currentLocale: "ru",\n'
#  '            imagesSiteUrl: "//images.wbstatic.net",\n'
#  '            staticSiteUrl: "//static-basket-01.wb.ru/vol0",\n'
#  '            staticBasketUrl: "//static-basket-01.wb.ru/vol0",\n'
#  '            staticFallbackUrl: "//static.wbstatic.net",\n'
#  '            staticBasketExtUrl: "//static-basket-01.wb.ru", \n'
#  '            fullDomainName: "",\n'
#  '            origin: "https://www.wildberries.ru",\n'
#  '            photosDomainUrl: "//photos.wbstatic.net",\n'
#  '            currencyShortName: "&#x20BD;",\n'
#  '            currencyCodeByLetters: "RUB",\n'
#  '            videoPath: "//video.wbstatic.net/video/",\n'
#  '            defaultCatalogImgSize: "c516x688",\n'
#  '            geo: {\n'
#  "                cookie: '__wbl'\n"
#  '            },\n'
#  '            cookie: {\n'
#  "                mobileClient: 'mobile_client'\n"
#  '            },\n'
#  '            googleMapsUrl: '
#  '"//maps.googleapis.com/maps/api/js?v=3.30&key=AIzaSyCImNLt0Uthh8XPUyDioKGmHhm45lH1Fy0&language=RU",\n'
#  '            yandexMapsUrl: '
#  '"//api-maps.yandex.ru/2.1/?lang=ru-RU&load=package.standard",\n'
#  '            yandexEnterpriseMapsUrl: function() {return wb.global.settings '
#  '&& wb.global.settings.switches && '
#  'wb.global.settings.switches.useFreeYandexMapsSite ? '
#  '"//api-maps.yandex.ru/2.1/?lang=ru-RU&load=package.standard" : '
#  '"//enterprise.api-maps.yandex.ru/2.1/?lang=ru-RU&load=package.standard&apikey=87dd0524-062c-4e56-b44d-3942721beced&suggest_apikey=0ebe3f4b-328f-4791-9382-746493053198";},\n'
#  '            feedbacksServiceUrl: '
#  "'https://public-feedbacks.wildberries.ru/api/v1/',\n"
#  '            questionsServiceUrl: '
#  "'https://questions.wildberries.ru/api/v1/',\n"
#  '            stores: {\n'
#  '                importStores : [124583,124584],\n'
#  '                preorder: []\n'
#  '            },\n'
#  '            supportedUICultures: '
#  '[{"name":"ru","lang":"ru","nativeName":"русский"}]\n'
#  '        };\n'
#  '    \n'
#  '</script>\n'
#  '    \n'
#  '\n'
#  '    \n'
#  '    <!--noindex-->\n'
#  '    <!-- Wb Analytics -->\n'
#  '<script>\n'
#  '    (function(w,d,s,c,t,a,m){\n'
#  '        w[t]=w[t]||function(){\n'
#  '            (w[t].q=w[t].q||[]).push(arguments)\n'
#  '        },w[t].l=1*new Date();\n'
#  '        a=d.createElement(s), m=d.getElementsByTagName(s)[0];\n'
#  '        a.async=1;\n'
#  '        a.src=c;\n'
#  '        m.parentNode.insertBefore(a,m)})\n'
#  "    (window,document,'script','https://a.wb.ru/sdk/sdk.js','wba');\n"
#  '    wba("init", {"counterId": 4, "cookieDomain": ".wildberries.ru"});\n'
#  '    wba("pageview");\n'
#  '</script>\n'
#  '<!-- End Wb Analytics -->\n'
#  '\n'
#  '    <!--/noindex-->\n'
#  '    \n'
#  '    \n'
#  '        <script type="text/javascript" '
#  'src="//static-basket-01.wb.ru/vol0/r/js-templates-ru-ru.9.3.135.js?" '
#  '></script>\n'
#  '        <script type="text/javascript" '
#  'src="//static-basket-01.wb.ru/vol0/r/route-data-ru.9.3.135.js?" ></script>\n'
#  '\n'
#  '\n'
#  '    \n'
#  '        <div class="popup popup-confirm-age j-popup-confirm-age">\n'
#  '    <button class="popup__close j-confirm-age-close" '
#  'type="button">Закрыть</button>\n'
#  '    <div class="popup__content">\n'
#  '        <h2 class="popup__header">Подтвердите свой возраст</h2>\n'
#  '        <p>Данный раздел предназначен только для посетителей, достигших '
#  'возраста 18 лет!</p>\n'
#  '        <div class="popup__btn">\n'
#  '            <button type="button" class="popup__btn-main j-confirm" '
#  'data-link="{on confirm}">Да, мне есть 18 лет</button>\n'
#  '            <button type="button" class="popup__btn-base '
#  'j-confirm-age-close" data-link="{on decline}">Нет</button>\n'
#  '        </div>\n'
#  '    </div>\n'
#  '</div>\n'
#  '    \n'
#  '</body>\n'
#  '\n'
#  '</html>\n'
#  '\n')
